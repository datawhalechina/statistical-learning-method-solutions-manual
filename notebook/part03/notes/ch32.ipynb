# %% [markdown]
# # 第32章 扩散模型

# %% [markdown]
# ## 习题32.1

# %% [markdown]
# &emsp;&emsp;DDPM的前向过程中，当 $t$ 趋于无穷时，转移概率分布 $q(\boldsymbol{x}_t | \boldsymbol{x}_{t-1})$ 趋于标准高斯分布。说明原因。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.2

# %% [markdown]
# &emsp;&emsp;实现DDPM的学习和生成算法。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.3

# %% [markdown]
# &emsp;&emsp;实现朗之万动力学的采样算法，并应用于图32.4的高斯混合模型的数据采样。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.4

# %% [markdown]
# &emsp;&emsp;整理DDPM的分数函数形式的学习算法和生成算法，列出与SMLD的不同点。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.5

# %% [markdown]
# &emsp;&emsp;证明一元高斯分布 $x \sim p(x) = N(x; \mu, \sigma^2)$ 的 Tweedie 公式，其中数据 $x$ 是随机变量，均值 $\mu$ 是随机变量，方差 $\sigma^2$ 是定量。
# $$
# \mathbb{E} [\mu|x] = x + \sigma^2 \frac{d}{dx} \log p(x)
# $$

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.6

# %% [markdown]
# &emsp;&emsp;验证DDPM 和 SMLD 的随机微分方程SDE满足定理32.2。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**

# %% [markdown]
# ## 习题32.7

# %% [markdown]
# &emsp;&emsp;推导无分类器引导的分数函数形式
# $$
# \nabla_{\boldsymbol{x}_t} \log p_{\boldsymbol{\theta}} (\boldsymbol{x}_t | y) = \gamma \boldsymbol{s}_{\boldsymbol{\theta}} (\boldsymbol{x}_t, t, y) + (1 - \gamma) \boldsymbol{s}_{\boldsymbol{\theta}} (\boldsymbol{x}_t, t)
# $$
# 其中，$\gamma$ 是系数。

# %% [markdown]
# **解答：**

# %% [markdown]
# **解答思路：**

# %% [markdown]
# **解答步骤：**
